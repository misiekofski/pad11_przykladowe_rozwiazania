# %%
import requests
import os
import re

from time import sleep
from bs4 import BeautifulSoup

# %%
def get_page_jobs(page) -> list:
    """
    Ze strony głównej NoFluffJobs pobiera listę ofer pracy i zwraca list zawieracjącą słownik {job_id, job_url}

    @param page: BeufitifulSoup strony
    @returns: lista ze słownikami {job_id, job_url}
    """
    # znajdujemy oferty pracy dostępne na stronie (przykład znalezienie)
    # poprzez znalezienie obrazka oraz jego rodzica
    jobs = [x.parent for x in page.find_all('div', class_='posting-image')]

    result = []  # zmienna z informacjami wyjściowymi
    for job in jobs:
        id = job['id']  # id oferty
        url = job['href']  # url do oferty

        # dodajemy informacje do zmiennej wynikowej
        result.append({'job_id': id, 'job_url': url})

    return result

# %%
def is_empty_page(page) -> bool:
    """
    Sprawdza czy strona jest pusta
    """
    empty_condition = page.find('h2', class_='text-white font-weight-bold')

    if empty_condition is None:
        return False
    else:
        return True

# %%
def get_contract_type(type_: str) -> str:
    if type_.find('B2B') > 0:
        return 'B2B'
    elif type_.find('dzieło') > 0:
        return 'UoD'
    elif type_.find('zlecenie') > 0:
        return 'UZ'
    elif type_.find('pracę') > 0:
        return 'UoP'
    return 'N/F'

# %%
def parse_salary(salary) -> dict:
    bounds = re.findall('[0-9]+', salary)
    low_bound = bounds[0]
    high_bound = bounds[1] if len(bounds) > 1 else bounds[0]
    currency = salary.split()[-1]

    return {'low': low_bound,
            'high': high_bound,
            'currency': currency}

# %%
def get_job_data(bs) -> dict:
    if is_empty_page(bs):
        return

    header_bs = bs.find(id='posting-header')
    job_title = header_bs.find('h1').string
    company_name = header_bs.find('dd').string

    salary_bs = bs.find('nfj-posting-salaries-list')
    salaries = salary_bs.find_all(class_='salary')
    types = [s.find('p').text for s in salaries]

    salaries = [x.find('h4').text for x in salaries]
    salaries = [parse_salary(x) for x in salaries]

    types_cleaned = [get_contract_type(x) for x in types]

    salary_data = zip(types_cleaned, salaries)
    salary_data = dict(salary_data)

    additional_info_bs = bs.find('div', class_='additional-info-row')

    try:
        locations = additional_info_bs.find('li', class_='text-break').text

        locations = locations.replace('(Po pandemii)', '')
        locations = locations.replace('location_on', '')
        
        locations = [x.strip() for x in locations.split(',')]
    except AttributeError:
        locations = ['N/A']
        
    results = {}
    results['job_title'] = job_title.strip()
    results['company'] = company_name.strip()
    
    results['salary'] = salary_data 
    results['locations'] = locations

    return results

# %%
offers = []
data_path = '../data/raw'

for entry in os.scandir(data_path):
    print('Processing ' + entry.name)

    with open(os.path.join(data_path, entry.name), encoding='UTF-8') as f:
        html = f.read()

    bs = BeautifulSoup(html)
    offers += get_page_jobs(bs)
# Out:
# Processing data analyst_1_20210317_121632.html
# Processing data analyst_2_20210317_121632.html
# Processing data engineer_1_20210317_121632.html
# Processing data engineer_2_20210317_121632.html
# Processing data engineer_3_20210317_121632.html
# Processing data engineer_4_20210317_121632.html
# Processing data scientist_1_20210317_121632.html

# %%
results = []
i = 1
for offer in offers:
    print(i)
    print(offer['job_url'])

    timeout = 0
    while timeout < 10:
        try:
            url = 'https://nofluffjobs.com' + offer['job_url']
            r = requests.get(url)
            x = get_job_data(BeautifulSoup(r.text))
            break
        except AttributeError:
            print('Timeout {} of 10'.format(timeout))
            timeout += 1
            sleep(5)
        if timeout == 10:
            x = None
            break

    if x:
        x['id'] = i
        results.append(x)

    sleep(5)
    i+=1
# Out:
# 1
# /pl/job/ux-ui-designer-hl-tech-warsaw-g8dhirzb
# 2
# /pl/job/power-bi-data-analyst-devire-warszawa-dkwkjy8e
# 3
# /pl/job/data-analyst-iiit-warszawa-yzunafaq
# 4
# /pl/job/senior-data-analyst-devire-remote-zpig62pp
# 5
# /pl/job/office-manager-prime-force-warsaw-v8b03tip
# 6
# /pl/job/senior-power-bi-developer-lingaro-remote-zkfyy6qe
# 7
# /pl/job/data-analyst-business-intelligence-westwing-robakowo-1aqisyg9
# 8
# /pl/job/technical-product-devops-kyp-ai-remote-fwv28vkw
# 9
# /pl/job/tester-data-analyst-dpdgroup-it-solutions-warszawa-dvrkq1gg
# 10
# /pl/job/business-analyst-ework-group-gdansk-mdac2ic9
# 11
# /pl/job/data-scientist-gfk-polonia-warszawa-ivqru8sq
# 12
# /pl/job/big-data-analyst-solid-bridge-solutions-warsaw-vg3i0mzi
# 13
# /pl/job/senior-python-developer-data-science-astek-polska-remote-sorrjdky
# 14
# /pl/job/data-scientist-tidio-remote-s0vwd0hw
# 15
# /pl/job/business-analyst-prodata-consult-gdansk-wy5irucl
# 16
# /pl/job/business-analyst-qlogix-krakow-2nadvpc5
# 17
# /pl/job/sap-business-training-coordinator-opel-manufacturing-poland-sp-o-o-gliwice-xxrhv3my
# 18
# /pl/job/senior-product-manager-precursive-ltd-remote-dhqeutsc
# 19
# /pl/job/data-scientist-samba-tv-warszawa-raxc2ubf
# 20
# /pl/job/it-analyst-prodata-consult-warsaw-cele3gqg
# 21
# /pl/job/technical-solutions-specialist-np-rtb-house-remote-z3ol3u9f
# 22
# /pl/job/data-analyst-prodata-consult-warsaw-xc9qvnag
# 23
# /pl/job/data-engineer-sql-bi-umlaut-remote-frf4kno7
# 24
# /pl/job/data-analytics-implementation-specialist-iiit-remote-j0elobgg
# Timeout 0 of 10
# 25
# /pl/job/business-intelligence-analyst-tylko-remote-rylbe3dq
# 26
# /pl/job/data-scientist-iot-nexer-group-remote-knjpmauz
# 27
# /pl/job/product-owner-dpdgroup-it-solutions-hungary-kft-budapest-cyfvzyna
# 28
# /pl/job/frontend-developer-evotrex-zrt-budapest-kpddtnmq
# 29
# /pl/job/lead-big-data-software-engineer-epam-remote-psic4swk
# 30
# /pl/job/senior-big-data-software-engineer-epam-remote-tmxgfsq2
# 31
# /pl/job/big-data-engineer-akamai-technologies-krakow-opr7jc69
# 32
# /pl/job/cloud-integration-engineer-starburst-warszawa-yex9ozt3
# 33
# /pl/job/java-engineer-engine-presto-starburst-warszawa-ib8og7iw
# 34
# /pl/job/endpoint-manager-avenga-wroclaw-tz2eofn4
# 35
# /pl/job/senior-ruby-on-rails-engineer-remote-sonarhome-vkftkq48
# 36
# /pl/job/big-data-devops-engineer-iiit-warszawa-hpbjnlfc
# 37
# /pl/job/machine-learning-engine-data-scientist-idego-group-remote-0uatzfro
# 38
# /pl/job/remote-data-network-engineer-general-dynamics-mission-systems-fvfav4mw
# 39
# /pl/job/software-engineer-mobile-developer-ios-smartpatient-business-services-warsaw-laaaebrz
# 40
# /pl/job/data-engineer-mid-senior-smartpatient-business-services-warszawa-uy4ln9hn
# 41
# /pl/job/data-engineer-informtica-mdm-onwelo-remote-a8jlnlfw
# 42
# /pl/job/remote-cloud-data-engineer-acaisoft-poland-drzdjeu6
# 43
# /pl/job/senior-data-engineer-devire-katowice-lqv2igv9
# 44
# /pl/job/data-engineer-prodata-consult-remote-4ngazjvd
# 45
# /pl/job/senior-data-science-engineer-capgemini-wroclaw-qskjb7aj
# 46
# /pl/job/okta-engineer-with-python-acaisoft-remote-a2wf1d5n
# 47
# /pl/job/data-engineer-data-architect-apreel-warszawa-yps7uzex
# 48
# /pl/job/big-data-engineer-alcon-warszawa-oeek1ifs
# 49
# /pl/job/senior-data-engineer-devsdata-llc-remote-8l1hizhj
# 50
# /pl/job/remote-senior-big-data-engineer-rtb-house-yzet3m9q
# 51
# /pl/job/machine-learning-engineer-rtb-house-remote-b2fp8h41
# 52
# /pl/job/senior-data-engineer-prodata-consult-warszawa-v3un3ol7
# 53
# /pl/job/data-engineer-alcon-warszawa-ilbtxvmg
# 54
# /pl/job/big-data-engineer-getindata-remote-krcucwos
# 55
# /pl/job/data-engineer-stx-next-remote-h1bhnv9g
# 56
# /pl/job/network-engineer-l1-link-group-remote-1awa9qn8
# 57
# /pl/job/expert-python-engineer-aws-payability-remote-ikoywhi3
# 58
# /pl/job/ai-data-engineer-with-scala-lingaro-warsaw-hznc7gpi
# 59
# /pl/job/senior-software-engineer-big-data-adform-warsaw-epncsi8m
# 60
# /pl/job/software-engineer-scala-big-data-adform-warsaw-4rblsw5u
# 61
# /pl/job/remote-apigee-engineer-acaisoft-acaisoft-poland-lkpd2xae
# 62
# /pl/job/full-stack-engineer-starburst-warszawa-uitjqxsl
# 63
# /pl/job/data-science-engineer-mindbox-warszawa-tkwgkar9
# 64
# /pl/job/remote-google-cloud-architect-link-group-jc2myjj6
# 65
# /pl/job/data-protection-engineer-link-group-krakow-jszah4mp
# 66
# /pl/job/senior-data-engineer-idemia-remote-tkb0lw8i
# 67
# /pl/job/data-protection-engineer-link-group-krakow-b8yv8bxn
# 68
# /pl/job/data-engineer-spica-solutions-warszawa-icvdyhv8
# 69
# /pl/job/gcp-devops-engineer-getindata-remote-gwpwfwnl
# 70
# /pl/job/data-engineer-itmagination-remote-h9awd0j6
# 71
# /pl/job/bi-engineer-itmagination-remote-d2l1zfec
# 72
# /pl/job/data-engineer-ai-avanade-poland-krakow-09cuzbh6
# 73
# /pl/job/bi-data-engineer-link-group-remote-uixk8ubu
# 74
# /pl/job/mid-senior-backend-engineer-python-payability-katowice-bkocpl7t
# 75
# /pl/job/remote-senior-apigee-engineer-acaisoft-poland-wk0zp5ud
# Timeout 0 of 10
# 76
# /pl/job/senior-apigee-engineer-acaisoft-poland-bialystok-y56kxqx7
# 77
# /pl/job/data-scientist-samba-tv-warszawa-raxc2ubf
# 78
# /pl/job/senior-expert-python-engineer-virtuslab-remote-ylfwxoee
# 79
# /pl/job/big-data-software-engineer-ergo-technology-services-warszawa-hixck6ru
# 80
# /pl/job/senior-big-data-engineer-solid-bridge-solutions-warszawa-kt67d1ru
# 81
# /pl/job/data-engineer-solid-bridge-solutions-warszawa-yvfvhpy4
# 82
# /pl/job/data-quality-engineer-avenga-warsaw-botwhiac
# 83
# /pl/job/senior-big-data-engineer-devire-remote-pff3f9cp
# 84
# /pl/job/data-engineer-with-bash-shell-sii-polska-warszawa-4mtfss63
# 85
# /pl/job/senior-data-engineer-netguru-remote-foriw5qq
# 86
# /pl/job/senior-software-engineer-python-clearcode-wroclaw-xlwnxlgj
# 87
# /pl/job/data-engineer-devire-warszawa-ha9xyqvv
# 88
# /pl/job/data-engineer-sql-bi-umlaut-remote-frf4kno7
# 89
# /pl/job/senior-software-engineer-with-dicom-acaisoft-remote-qlftem0i
# 90
# /pl/job/senior-data-infrastructure-engineer-brainly-remote-ug8bml1d
# 91
# /pl/job/cloud-data-engineer-acaisoft-poland-bialystok-i6uaovw1
# 92
# /pl/job/data-engineer-link-group-warszawa-7tlsx1da
# 93
# /pl/job/data-engineer-nexer-remote-3850jw1a
# 94
# /pl/job/data-engineer-idbc-creative-solutions-kft-remote-kcpi3g9g
# 95
# /pl/job/remote-data-engineer-starschema-kft-3m7patxf
# 96
# /pl/job/climate-risk-software-engineer-msci-budapest-rzvcfmss
# 97
# /pl/job/data-engineer-starjobs-magyarorszag-kft-budapest-dqfpu4hm
# 98
# /pl/job/climate-risk-software-engineer-lead-msci-budapest-pry2tsxn
# 99
# /pl/job/cloud-data-software-engineer-msci-budapest-gkyvhdla
# 100
# /pl/job/senior-data-scientist-silent-eight-pte-ltd-remote-lylz60xw
# 101
# /pl/job/data-scientist-axiom-health-gdansk-orndc5ye
# 102
# /pl/job/machine-learning-engine-data-scientist-idego-group-remote-0uatzfro
# 103
# /pl/job/senior-data-scientist-smartpatient-business-services-warszawa-d4mze0lo
# 104
# /pl/job/data-scientist-nowcasting-ai-wroclaw-wecagwmk
# 105
# /pl/job/senior-data-scientist-upc-polska-remote-qhpki9kc
# 106
# /pl/job/senior-data-scientist-syncron-warszawa-vh9nvvkb
# 107
# /pl/job/data-scientist-allegro-warsaw-tlkkxzww
# 108
# /pl/job/data-scientist-gfk-polonia-warszawa-ivqru8sq
# 109
# /pl/job/data-scientist-tidio-remote-s0vwd0hw
# 110
# /pl/job/remote-senior-data-scientist-idego-group-9f6alanr
# 111
# /pl/job/data-scientist-xplus-remote-iysgofsj
# 112
# /pl/job/data-scientist-samba-tv-warszawa-raxc2ubf
# 113
# /pl/job/lead-data-scientist-axiom-health-gdansk-z9t3wppn
# 114
# /pl/job/data-scientist-masterborn-remote-4889g6n8
# 115
# /pl/job/data-scientist-pixel-technology-lodz-uyuwpp9q
# 116
# /pl/job/senior-data-scientist-avenga-remote-hyxwjaqr
# 117
# /pl/job/data-scientist-iot-nexer-group-remote-knjpmauz

# %%
results
# Out:
# ob_title': 'Data Scientist',
#   'company': 'Tidio',
#   'salary': {'B2B': {'low': '15000', 'high': '22000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Business Analyst',
#   'company': 'ProData Consult',
#   'salary': {'B2B': {'low': '16800', 'high': '18480', 'currency': 'PLN'}},
#   'locations': ['Gdańsk']},
#  {'job_title': 'Business Analyst',
#   'company': 'Qlogix sp. z o. o.',
#   'salary': {'B2B': {'low': '9000', 'high': '15000', 'currency': 'PLN'},
#    'UoP': {'low': '11000', 'high': '11000', 'currency': 'PLN'}},
#   'locations': ['Kraków']},
#  {'job_title': 'SAP Business Training Coordinator',
#   'company': 'Opel Manufacturing Poland Sp. o.o.',
#   'salary': {'UoP': {'low': '6000', 'high': '8000', 'currency': 'PLN'}},
#   'locations': ['Gliwice']},
#  {'job_title': 'Senior Product Manager',
#   'company': 'Precursive Ltd',
#   'salary': {'B2B': {'low': '14000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Data Scientist',
#   'company': 'Samba TV',
#   'salary': {'B2B': {'low': '11000', 'high': '14500', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'IT Analyst',
#   'company': 'ProData Consult',
#   'salary': {'B2B': {'low': '20160', 'high': '21840', 'currency': 'PLN'}},
#   'locations': ['Warsaw', 'Tricity']},
#  {'job_title': 'Technical Solutions Specialist NP',
#   'company': 'RTB House',
#   'salary': {'B2B': {'low': '6000', 'high': '10000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Data Analyst',
#   'company': 'Prodata Consult',
#   'salary': {'B2B': {'low': '16800', 'high': '18480', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Data Engineer (SQL, BI)',
#   'company': 'umlaut Sp. z o.o.',
#   'salary': {'UoP': {'low': '7500', 'high': '15000', 'currency': 'PLN'}},
#   'locations': ['Szczecin']},
#  {'job_title': 'Data Analytics Implementation Specialist',
#   'company': 'IIIT',
#   'salary': {'B2B': {'low': '10000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Business Intelligence Analyst',
#   'company': 'Tylko',
#   'salary': {'B2B': {'low': '8000', 'high': '12000', 'currency': 'PLN'},
#    'UoP': {'low': '8000', 'high': '12000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Scientist (IoT)',
#   'company': 'Nexer Group',
#   'salary': {'B2B': {'low': '14448', 'high': '21840', 'currency': 'PLN'},
#    'UoP': {'low': '12000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Wrocław']},
#  {'job_title': 'Product Owner',
#   'company': 'DPDgroup IT Solutions Hungary Kft',
#   'salary': {'UoP': {'low': '10028', 'high': '11281', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Frontend Developer',
#   'company': 'Evotrex Zrt.',
#   'salary': {'UoP': {'low': '7521', 'high': '11281', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Lead Big Data Software Engineer',
#   'company': 'EPAM',
#   'salary': {'B2B': {'low': '21840', 'high': '28560', 'currency': 'PLN'},
#    'UoP': {'low': '18000', 'high': '24000', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Katowice', 'Gdańsk', 'Wrocław', 'Kraków']},
#  {'job_title': 'Senior Big Data Software Engineer',
#   'company': 'EPAM',
#   'salary': {'B2B': {'low': '15120', 'high': '21840', 'currency': 'PLN'},
#    'UoP': {'low': '13000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Katowice', 'Warszawa', 'Kraków', 'Wrocław', 'Gdańsk']},
#  {'job_title': 'Big Data Engineer',
#   'company': 'Akamai Technologies',
#   'salary': {'UoP': {'low': '14000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Kraków']},
#  {'job_title': 'Cloud Integration Engineer',
#   'company': 'Starburst',
#   'salary': {'B2B': {'low': '18000', 'high': '25000', 'currency': 'PLN'},
#    'UoP': {'low': '16000', 'high': '23000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Java Engineer (Engine Presto)',
#   'company': 'Starburst',
#   'salary': {'B2B': {'low': '16000', 'high': '25000', 'currency': 'PLN'},
#    'UoP': {'low': '14000', 'high': '23000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Endpoint Manager',
#   'company': 'AVENGA',
#   'salary': {'B2B': {'low': '15120', 'high': '18480', 'currency': 'PLN'},
#    'UoP': {'low': '11000', 'high': '14000', 'currency': 'PLN'}},
#   'locations': ['Wrocław']},
#  {'job_title': 'Senior Ruby on Rails Engineer [remote]',
#   'company': 'SonarHome S.A.',
#   'salary': {'B2B': {'low': '15000', 'high': '20000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Big Data DevOps Engineer',
#   'company': 'IIIT',
#   'salary': {'B2B': {'low': '12000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Machine Learning Engine / Data Scientist',
#   'company': 'Idego Group Sp. z o.o.',
#   'salary': {'B2B': {'low': '19000', 'high': '23000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Remote Data network engineer',
#   'company': 'General Dynamics Mission Systems',
#   'salary': {'B2B': {'low': '6909', 'high': '13819', 'currency': 'PLN'}},
#   'locations': ['Rumia']},
#  {'job_title': 'Software Engineer/Mobile Developer (iOS)',
#   'company': 'Smartpatient Business Services',
#   'salary': {'B2B': {'low': '15000', 'high': '24000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Data Engineer (Mid-Senior)',
#   'company': 'Smartpatient Business Services Sp z o.o.,',
#   'salary': {'B2B': {'low': '14000', 'high': '25000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Engineer (Informtica MDM)',
#   'company': 'Onwelo',
#   'salary': {'B2B': {'low': '14700', 'high': '17850', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Remote Cloud Data Engineer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Białystok', 'Warszawa', 'Gdynia']},
#  {'job_title': 'Senior Data Engineer',
#   'company': 'Devire',
#   'salary': {'UoP': {'low': '15000', 'high': '21000', 'currency': 'PLN'}},
#   'locations': ['Katowice']},
#  {'job_title': 'Data Engineer',
#   'company': 'ProData Consult',
#   'salary': {'B2B': {'low': '13440', 'high': '21840', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Mid/Senior Data Science Engineer',
#   'company': 'Capgemini',
#   'salary': {'UoP': {'low': '8000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Wrocław', 'Poznań']},
#  {'job_title': 'Okta Engineer with Python',
#   'company': 'Acaisoft',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Białystok', 'Gdynia']},
#  {'job_title': 'Big Data Engineer',
#   'company': 'Alcon',
#   'salary': {'UoP': {'low': '14000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Senior Data Engineer',
#   'company': 'DevsData LLC',
#   'salary': {'B2B': {'low': '26000', 'high': '30000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Remote Senior Big Data Engineer',
#   'company': 'RTB House',
#   'salary': {'B2B': {'low': '16800', 'high': '29400', 'currency': 'PLN'}},
#   'locations': ['Warsaw', 'Kraków']},
#  {'job_title': 'Machine Learning Engineer',
#   'company': 'RTB House',
#   'salary': {'B2B': {'low': '21000', 'high': '31500', 'currency': 'PLN'}},
#   'locations': ['Warsaw', 'Kraków']},
#  {'job_title': 'Senior Data Engineer',
#   'company': 'ProData Consult',
#   'salary': {'B2B': {'low': '23520', 'high': '28560', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Engineer',
#   'company': 'Alcon',
#   'salary': {'UoP': {'low': '14000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Big Data Engineer',
#   'company': 'GetInData',
#   'salary': {'B2B': {'low': '20160', 'high': '30240', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Engineer',
#   'company': 'STX Next',
#   'salary': {'B2B': {'low': '15120', 'high': '18480', 'currency': 'PLN'}},
#   'locations': ['Poznań', 'Wrocław', 'Łódź', 'Katowice', 'Gdańsk']},
#  {'job_title': 'Network Engineer - L1',
#   'company': 'Link Group Sp. z o. o.',
#   'salary': {'B2B': {'low': '8500', 'high': '11000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Expert Python Engineer (AWS)',
#   'company': 'Payability',
#   'salary': {'B2B': {'low': '20160', 'high': '35280', 'currency': 'PLN'}},
#   'locations': ['Katowice', 'Warszawa']},
#  {'job_title': 'AI Data Engineer with Scala',
#   'company': 'Lingaro',
#   'salary': {'B2B': {'low': '11760', 'high': '21840', 'currency': 'PLN'}},
#   'locations': ['Warsaw', 'Lublin']},
#  {'job_title': 'Senior Software Engineer | Big Data',
#   'company': 'Adform Sp. z o.o.',
#   'salary': {'UoP': {'low': '20000', 'high': '24000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Software Engineer (Scala) | Big Data',
#   'company': 'Adform Sp. z o.o.',
#   'salary': {'UoP': {'low': '18000', 'high': '21000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Remote Apigee Engineer (Acaisoft)',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Białystok', 'Warszawa', 'Gdynia']},
#  {'job_title': 'Full Stack Engineer',
#   'company': 'Starburst',
#   'salary': {'B2B': {'low': '16000', 'high': '25000', 'currency': 'PLN'},
#    'UoP': {'low': '14000', 'high': '23000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Science Engineer',
#   'company': 'Mindbox S.A.',
#   'salary': {'B2B': {'low': '17000', 'high': '22000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Remote Google Cloud Architect',
#   'company': 'Link Group Sp. z o. o.',
#   'salary': {'B2B': {'low': '26880', 'high': '33600', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Kraków']},
#  {'job_title': 'Data Protection Engineer',
#   'company': 'Link Group Sp. z o. o.',
#   'salary': {'B2B': {'low': '15000', 'high': '17000', 'currency': 'PLN'},
#    'UoP': {'low': '15000', 'high': '17000', 'currency': 'PLN'}},
#   'locations': ['Kraków']},
#  {'job_title': 'Senior Data Engineer',
#   'company': 'Idemia',
#   'salary': {'B2B': {'low': '16800', 'high': '31500', 'currency': 'PLN'},
#    'UoP': {'low': '11000', 'high': '17000', 'currency': 'PLN'}},
#   'locations': ['Łódź']},
#  {'job_title': 'Data Protection Engineer',
#   'company': 'Link Group Sp. z o. o.',
#   'salary': {'UoP': {'low': '15000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Kraków']},
#  {'job_title': 'Data Engineer',
#   'company': 'Spica Solutions',
#   'salary': {'B2B': {'low': '12000', 'high': '15000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'GCP DevOps Engineer',
#   'company': 'GetInData',
#   'salary': {'B2B': {'low': '20000', 'high': '30000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Data Engineer',
#   'company': 'ITMAGINATION',
#   'salary': {'B2B': {'low': '15000', 'high': '24000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'BI Engineer',
#   'company': 'ITMAGINATION',
#   'salary': {'B2B': {'low': '15000', 'high': '24000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Data Engineer/AI',
#   'company': 'Avanade Poland',
#   'salary': {'B2B': {'low': '13440', 'high': '21000', 'currency': 'PLN'},
#    'UoP': {'low': '10000', 'high': '17000', 'currency': 'PLN'}},
#   'locations': ['Kraków', 'Wrocław', 'Rzeszów']},
#  {'job_title': 'BI Data Engineer',
#   'company': 'Link Group Sp. z o. o.',
#   'salary': {'B2B': {'low': '15120', 'high': '18480', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Gdańsk', 'Kraków']},
#  {'job_title': 'Mid/Senior Backend Engineer (Python)',
#   'company': 'Payability',
#   'salary': {'B2B': {'low': '16800', 'high': '21840', 'currency': 'PLN'},
#    'UoP': {'low': '16800', 'high': '21840', 'currency': 'PLN'}},
#   'locations': ['Katowice', 'Warszawa', 'Wrocław']},
#  {'job_title': 'Remote Senior Apigee Engineer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Białystok', 'Warszawa', 'Gdynia']},
#  {'job_title': 'Senior Apigee Engineer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Białystok', 'Warszawa', 'Gdynia']},
#  {'job_title': 'Data Scientist',
#   'company': 'Samba TV',
#   'salary': {'B2B': {'low': '11000', 'high': '14500', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Senior/Expert Python Engineer',
#   'company': 'VirtusLab',
#   'salary': {'B2B': {'low': '16000', 'high': '25000', 'currency': 'PLN'}},
#   'locations': ['Krakow']},
#  {'job_title': 'Big Data Software Engineer',
#   'company': 'ERGO Technology & Services S.A.',
#   'salary': {'UoP': {'low': '12000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Senior Big Data Engineer',
#   'company': 'Solid Bridge Solutions Sp. z o.o.',
#   'salary': {'UoP': {'low': '14000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Engineer',
#   'company': 'Solid Bridge Solutions Sp. z o.o.',
#   'salary': {'UoP': {'low': '13000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Quality Engineer',
#   'company': 'AVENGA',
#   'salary': {'B2B': {'low': '19320', 'high': '25200', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Senior Big Data Engineer',
#   'company': 'Devire',
#   'salary': {'B2B': {'low': '25200', 'high': '26880', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Data Engineer with Bash/Shell',
#   'company': 'Sii Polska',
#   'salary': {'B2B': {'low': '18900', 'high': '23100', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Senior Data Engineer',
#   'company': 'Netguru S.A.',
#   'salary': {'B2B': {'low': '15800', 'high': '24000', 'currency': 'PLN'},
#    'UoP': {'low': '13200', 'high': '20000', 'currency': 'PLN'}},
#   'locations': ['Poznań',
#    'Warszawa',
#    'Kraków',
#    'Wrocław',
#    'Gdańsk',
#    'Białystok',
#    'Katowice',
#    'Łódź']},
#  {'job_title': 'Senior Software Engineer (Python)',
#   'company': 'Clearcode',
#   'salary': {'B2B': {'low': '13000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Wrocław']},
#  {'job_title': 'Data Engineer',
#   'company': 'Devire',
#   'salary': {'UoP': {'low': '13000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Engineer (SQL, BI)',
#   'company': 'umlaut Sp. z o.o.',
#   'salary': {'UoP': {'low': '7500', 'high': '15000', 'currency': 'PLN'}},
#   'locations': ['Szczecin']},
#  {'job_title': 'Senior Software Engineer with DICOM',
#   'company': 'Acaisoft',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Białystok', 'Gdynia']},
#  {'job_title': 'Cloud Data Engineer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'salary': {'B2B': {'low': '13600', 'high': '18400', 'currency': 'PLN'}},
#   'locations': ['Białystok', 'Warszawa', 'Gdynia']},
#  {'job_title': 'Data Engineer',
#   'company': 'Link Group Sp. z o. o.',
#   'salary': {'B2B': {'low': '15120', 'high': '18480', 'currency': 'PLN'},
#    'UoP': {'low': '16000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Łódź', 'Kraków']},
#  {'job_title': 'Data Engineer',
#   'company': 'Nexer',
#   'salary': {'B2B': {'low': '15120', 'high': '22680', 'currency': 'PLN'},
#    'UoP': {'low': '12500', 'high': '18500', 'currency': 'PLN'}},
#   'locations': ['Wrocław']},
#  {'job_title': 'Data Engineer',
#   'company': 'IDBC Creative Solutions Kft.',
#   'salary': {'B2B': {'low': '16295', 'high': '16295', 'currency': 'PLN'},
#    'UoP': {'low': '8774', 'high': '15042', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Remote Data Engineer',
#   'company': 'Starschema Kft.',
#   'salary': {'UoP': {'low': '10028', 'high': '15042', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Climate Risk Software Engineer',
#   'company': 'MSCI',
#   'salary': {'UoP': {'low': '11281', 'high': '15042', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Data Engineer',
#   'company': 'Starjobs Magyarország Kft.',
#   'salary': {'UoP': {'low': '10028', 'high': '15042', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Climate Risk Software Engineer Lead',
#   'company': 'MSCI',
#   'salary': {'UoP': {'low': '18802', 'high': '20056', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Cloud Data Software Engineer',
#   'company': 'MSCI',
#   'salary': {'UoP': {'low': '11281', 'high': '15042', 'currency': 'PLN'}},
#   'locations': ['Budapest']},
#  {'job_title': 'Senior Data Scientist',
#   'company': 'Silent Eight Pte. Ltd.',
#   'salary': {'B2B': {'low': '15000', 'high': '21000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Data Scientist',
#   'company': 'Axiom Health',
#   'salary': {'B2B': {'low': '11000', 'high': '15000', 'currency': 'PLN'},
#    'UZ': {'low': '11000', 'high': '15000', 'currency': 'PLN'},
#    'UoD': {'low': '11000', 'high': '15000', 'currency': 'PLN'}},
#   'locations': ['Gdansk', 'Gdynia']},
#  {'job_title': 'Machine Learning Engine / Data Scientist',
#   'company': 'Idego Group Sp. z o.o.',
#   'salary': {'B2B': {'low': '19000', 'high': '23000', 'currency': 'PLN'}},
#   'locations': ['N/A']},
#  {'job_title': 'Senior Data Scientist',
#   'company': 'Smartpatient Business Services Sp z o.o.,',
#   'salary': {'B2B': {'low': '14000', 'high': '25000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Scientist',
#   'company': 'Nowcasting.Ai',
#   'salary': {'B2B': {'low': '17000', 'high': '30000', 'currency': 'PLN'}},
#   'locations': ['Wrocław']},
#  {'job_title': 'Senior Data Scientist',
#   'company': 'UPC Polska',
#   'salary': {'B2B': {'low': '16000', 'high': '16000', 'currency': 'PLN'},
#    'UoP': {'low': '11200', 'high': '15400', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Katowice']},
#  {'job_title': 'Senior Data Scientist',
#   'company': 'Syncron Sp. z o.o.',
#   'salary': {'UoP': {'low': '14000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Scientist',
#   'company': 'Allegro',
#   'salary': {'UoP': {'low': '12000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Warsaw']},
#  {'job_title': 'Data Scientist',
#   'company': 'GfK Polonia sp. z o.o.',
#   'salary': {'UoP': {'low': '9500', 'high': '12300', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Scientist',
#   'company': 'Tidio',
#   'salary': {'B2B': {'low': '15000', 'high': '22000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Remote Senior Data Scientist',
#   'company': 'Idego Group Sp. z o.o.',
#   'salary': {'B2B': {'low': '17000', 'high': '19000', 'currency': 'PLN'}},
#   'locations': ['Warszawa', 'Trójmiasto', 'Kraków', 'Wrocław', 'Poznań']},
#  {'job_title': 'Data Scientist',
#   'company': 'XPLUS S.A.',
#   'salary': {'B2B': {'low': '12000', 'high': '16000', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Data Scientist',
#   'company': 'Samba TV',
#   'salary': {'B2B': {'low': '11000', 'high': '14500', 'currency': 'PLN'}},
#   'locations': ['Warszawa']},
#  {'job_title': 'Lead Data Scientist',
#   'company': 'Axiom Health',
#   'salary': {'B2B': {'low': '22500', 'high': '27000', 'currency': 'PLN'}},
#   'locations': ['Gdansk']},
#  {'job_title': 'Data Scientist',
#   'company': 'MasterBorn',
#   'salary': {'B2B': {'low': '12000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Wrocław', 'Kielce', 'Opole', 'Szczecin', 'Bydgoszcz']},
#  {'job_title': 'Data Scientist',
#   'company': 'Pixel Technology Sp. z o.o.',
#   'salary': {'UoP': {'low': '6000', 'high': '10000', 'currency': 'PLN'}},
#   'locations': ['Łódź']},
#  {'job_title': 'Senior Data Scientist',
#   'company': 'AVENGA',
#   'salary': {'B2B': {'low': '16800', 'high': '21840', 'currency': 'PLN'}},
#   'locations': ['Gdynia']},
#  {'job_title': 'Data Scientist (IoT)',
#   'company': 'Nexer Group',
#   'salary': {'B2B': {'low': '14448', 'high': '21840', 'currency': 'PLN'},
#    'UoP': {'low': '12000', 'high': '18000', 'currency': 'PLN'}},
#   'locations': ['Wrocław']}]

# %%
x = results[-1]
x
# Out:
# {'job_title': 'Data Scientist (IoT)',
#  'company': 'Nexer Group',
#  'salary': {'B2B': {'low': '14448', 'high': '21840', 'currency': 'PLN'},
#   'UoP': {'low': '12000', 'high': '18000', 'currency': 'PLN'}},
#  'locations': ['Wrocław'],
#  'salary_types': ['job_title', 'company', 'salary', 'locations']}

# %%
import itertools as it
list(it.chain(x['salary'].values, x['locations']))
# Out:
# ['B2B', 'UoP', 'Wrocław']

# %%
salary_types = list(x['salary'].keys())

# %%
x['salary']
# Out:
# ['B2B', 'UoP']
