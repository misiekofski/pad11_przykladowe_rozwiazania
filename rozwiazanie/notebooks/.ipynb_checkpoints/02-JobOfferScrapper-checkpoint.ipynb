# %%
import pandas as pd
import re
import os

from bs4 import BeautifulSoup

# %%
def is_page_empty(bs) -> bool:
    empty_condition = bs.find('h2', class_='text-white font-weight-bold')

    if empty_condition is None:
        return False
    else:
        return True

# %%
def parse_salary(salary) -> dict:
    # pomijamy dziwne ogłoszenie firmy Alten
    if salary != '$':
        bounds = re.findall('[0-9]+', salary.replace(' ', ''))

        low_bound = bounds[0]+bounds[1]
        # paskudny hack
        high_bound = bounds[2]+bounds[3] if len(bounds) > 2 else bounds[0]+bounds[1]
        currency = salary.split()[-1]

        return {'low': low_bound,
                'high': high_bound,
                'currency': currency}

# %%
def parse_city(city) -> dict:
    # pomijamy navalgo z dolarem
    if re.search('(Zdalna)', city) or re.search('\d{2}', city):
         _city = "Zdalna"
         country = 'N/A'
    else:       
        (_city, country) = city.split(',')
        country = country.strip()

    return {'city': _city, 'country': country}

# %%
def parse_jobs(jobs) -> list:
    results = []
    
    for job in jobs:
        results.append(parse_job(job))

    return results

# %%
def parse_job(job) -> dict:
    job_info = job.find('div', class_='posting-info position-relative d-lg-flex flex-grow-1 align-items-center ng-star-inserted').find_all('span')
    
    salary = job_info[0].text.strip()
    salary_data = parse_salary(salary)
    
    location = job.find('nfj-posting-item-city')
    if location is None:
        location = job_info[1]

    location = location.text.strip()
    location = parse_city(location)

    name = job.find('h3', class_='posting-title__position').text.strip()
    
    company = job.find('span', class_='posting-title__company').text.replace('w', '').strip()

    technology = job.find('a', class_='btn btn-outline-secondary btn-sm text-truncate')
    if technology:
        technology = technology.text.strip()
    else:
        technology = 'N/A'

    return {
        'location': location,
        'salary': salary_data,
        'name': name,
        'company': company,
        'technology': technology
    }

# %%
def get_data(page) -> list:
    results = []

    jobs = [x.parent for x in page.find_all('div', class_='posting-image')]
    page_data = parse_jobs(jobs)
    results += page_data

    return results

# %%
data_dir = '../data/raw'
results = []

for entry in os.scandir(data_dir):
    with open(
        os.path.join(data_dir, entry.name),
        encoding='UTF-8') as f:
            html = f.read()

    job = entry.name.split('_')[0]
    bs = BeautifulSoup(html)
    offers = get_data(bs)
    for offer in offers:
        offer['job'] = job
    results += offers

# %%
offers
# Out:
# [{'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'EXATEL S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '20160', 'currency': 'PLN'},
#   'name': 'Java Developer (Mid/Senior)',
#   'company': 'BCF Softare Sp. z o. o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12600', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Clurgo Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14280', 'high': '19320', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Clurgo Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '6000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'KRUK S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Bydgoszcz', 'country': 'POL'},
#   'salary': {'low': '3000', 'high': '6000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'PRIMIGENIUS',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java/HTML Developer (Remote)',
#   'company': 'Exorigo-Upos',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Viercode',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '25200', 'high': '31920', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Link Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '19000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devire Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 3'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'BMS',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '30240', 'high': '35280', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer (Junior - Mid -Senior)',
#   'company': 'PayU',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '30240', 'currency': 'PLN'},
#   'name': 'JAVA SOFTWARE DEVELOPER',
#   'company': 'RMEDISON SP Z O.O.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '15000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Mid/Senior Java Developer',
#   'company': 'ERGO Technology & Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20160', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '5500', 'high': '8400', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'TouK',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '19000', 'currency': 'PLN'},
#   'name': 'Java Developer (100% remote)',
#   'company': 'PGS Softare S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Senior/Principal Java Developer',
#   'company': 'PGS Softare S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Full Stack Senior Java Developer',
#   'company': 'Sky and Space Co',
#   'technology': 'N/A',
#   'job': 'java developer'}]

# %%
df = pd.json_normalize(results)
df.head()
# Out:
#                            name             company technology  \
# 0     Full Stack Java Developer    Sky and Space Co        N/A
# 1                Java Developer  Contina Sp. z o.o.        N/A
# 2     Java Developer (with AWS)        ASTEK Polska        N/A
# 3         Junior Java Developer           Softarely        N/A
# 4  Junior Java/Groovy Developer     ProData Consult        N/A
#
#               job location.city location.country salary.low salary.high  \
# 0  java developer        Zdalna              N/A      16000       18000
# 1  java developer        Zdalna              N/A       7000       12000
# 2  java developer        Zdalna              N/A      21000       28350
# 3  java developer      Warszawa              POL      14700       18480
# 4  java developer      Warszawa              POL      10080       16800
#
#   salary.currency  salary
# 0             PLN     NaN
# 1             PLN     NaN
# 2             PLN     NaN
# 3             PLN     NaN
# 4             PLN     NaN

# %%
df.to_csv('../data/interim/job_offers.csv', sep=';', encoding='UTF', index=False)

# %%
results
# Out:
# [{'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Full Stack Java Developer',
#   'company': 'Sky and Space Co',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Contina Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '21000', 'high': '28350', 'currency': 'PLN'},
#   'name': 'Java Developer (with AWS)',
#   'company': 'ASTEK Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '14700', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Softarely',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10080', 'high': '16800', 'currency': 'PLN'},
#   'name': 'Junior Java/Groovy Developer',
#   'company': 'ProData Consult',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': None,
#   'name': 'Junior Java Developer',
#   'company': 'gravit.dev',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7560', 'high': '11760', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Decerto Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '5400', 'high': '7200', 'currency': 'PLN'},
#   'name': 'Junior Java Developer (remote)',
#   'company': 'Si e-commerce',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '23520', 'high': '26040', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devqube',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13440', 'high': '16800', 'currency': 'PLN'},
#   'name': 'Remote Mid Java Developer',
#   'company': 'People Trust Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15120', 'high': '21840', 'currency': 'PLN'},
#   'name': 'Java Developer | marketing automation',
#   'company': 'JCommerce Sp z o o',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15120', 'high': '21840', 'currency': 'PLN'},
#   'name': 'Senior Java Developer | microservices',
#   'company': 'JCommerce Sp z o o',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Kraków', 'country': 'POL'},
#   'salary': {'low': '12000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Java Fullstack Developer',
#   'company': 'SaldeoSMART',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7500', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Decerto Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Toro Performance',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '27000', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'Netguru S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'NVT Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '23520', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Remote Fullstack Java Developer',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 1'},
#   'salary': {'low': '5000', 'high': '7000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Storare Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 1'},
#   'salary': {'low': '5000', 'high': '7000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Storare Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Backend Developer',
#   'company': 'Datalizard Polska Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'Striped Giraffe Innovation & Strategy Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '31000', 'high': '35000', 'currency': 'PLN'},
#   'name': 'Java Developer Remote',
#   'company': 'Devire Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '19000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Kraków', 'country': 'POL'},
#   'salary': {'low': '12000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Rumble Fish Poland Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Java Developer (junior/mid)',
#   'company': 'Eversis sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Qurate Retail Group Global Business Services sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '26880', 'high': '31920', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'Devire Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13440', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Unity Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '22000', 'high': '27000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'YND Technologies',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9600', 'high': '11000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'ALTEN Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '9000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Horus Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '9000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Horus Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '21500', 'currency': 'PLN'},
#   'name': 'Java Backend Developer',
#   'company': 'Duco Technology Poland Sp.  z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '16800', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Codibly',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '25000', 'high': '29000', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Winged IT',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '19500', 'high': '28500', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'HL Tech',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '11000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'HL Tech',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '6000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'HL Tech',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Liki Mobile Solutions',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'SmartBear',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '6000', 'high': '9000', 'currency': 'PLN'},
#   'name': 'Remote Junior Java Developer',
#   'company': 'Channels',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Netcompany',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Kraków', 'country': 'POL'},
#   'salary': {'low': '6583', 'high': '12500', 'currency': 'PLN'},
#   'name': 'Graduate / Junior Java Developer Hybrid',
#   'company': 'HERE Technologies',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'itertatec sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'FIS Techlology Services (Poland) Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7000', 'high': '9000', 'currency': 'PLN'},
#   'name': 'Remote Junior Java Developer',
#   'company': 'Globema Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Kraków', 'country': 'POL'},
#   'salary': {'low': '12000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'AUTENTI',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11313', 'high': '17598', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Vidarex Kft.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9427', 'high': '18855', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Oncompass Medicine Hungary Kft.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10056', 'high': '17598', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Blackbelt Holding Zrt',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7542', 'high': '15084', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Flexion Mobile Plc Magyarországi Fióktelepe',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10056', 'high': '12570', 'currency': 'PLN'},
#   'name': 'Mid Backend Java Developer',
#   'company': 'Volksagen Group Services Kft.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11313', 'high': '15084', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Transpose Kft',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '13827', 'high': '17598', 'currency': 'PLN'},
#   'name': 'Medior Java Developer',
#   'company': 'Reed Hungary',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '12570', 'high': '18855', 'currency': 'PLN'},
#   'name': 'Medior/Senior Java Developer',
#   'company': 'Innovie Kft.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '16341', 'high': '20112', 'currency': 'PLN'},
#   'name': 'Lead Java developer',
#   'company': 'Blackbelt Holding Zrt',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '5656', 'high': '6285', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'DPDgroup IT Solutions Hungary Kft',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '8799', 'high': '13827', 'currency': 'PLN'},
#   'name': 'Market Risk Python/Java Developer',
#   'company': 'IDBC Creative Solutions Kft.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Debrecen', 'country': 'HUN'},
#   'salary': {'low': '22512', 'high': '32088', 'currency': 'PLN'},
#   'name': 'Mid/Senior Java Developer',
#   'company': 'Dynamic Solutions',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '11313', 'high': '20112', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Ideasol Magyarország Kft',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '9427', 'high': '18855', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Alvicom Kft.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '10056', 'high': '15084', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Fox and Wolf HR Solutions',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'EWL Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Backend Developer',
#   'company': 'Tellyo Oy Sp. z o.o. Oddział  Polsce',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '31000', 'high': '35000', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Devire Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '14000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Senior Java Developer (B2B)',
#   'company': 'Netcompany',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Junior/Mid Java Developer',
#   'company': 'IHS Markit',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14000', 'high': '19000', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'IHS Markit',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Britenet',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Britenet',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '23500', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'Britenet',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '19000', 'currency': 'PLN'},
#   'name': 'Mid Java Developer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '23000', 'high': '27000', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'Britenet',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '25000', 'high': '32000', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Fullstack Developer',
#   'company': 'Aurelis Consulting',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '25200', 'high': '30240', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Sygnity',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '17000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Sensi Labs Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '26000', 'currency': 'PLN'},
#   'name': 'Senior Java Backend Developer',
#   'company': 'Kitopi',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '5500', 'high': '9500', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'COMP S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Białystok', 'country': 'POL'},
#   'salary': {'low': '9000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Mid/Senior Java Developer',
#   'company': 'cronn Polska sp z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14000', 'high': '24000', 'currency': 'PLN'},
#   'name': '(Senior) Java Developer',
#   'company': 'Onelo S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '4200', 'high': '6000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Altkom Softare & Consulting',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '9000', 'high': '15000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Enamor International Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Bydgoszcz', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Fullstack Java Developer',
#   'company': 'Bersi Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Experienced Java Developer',
#   'company': 'Bluestone PIM',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'GDAŃSK', 'country': 'POL'},
#   'salary': {'low': '15000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Experienced Java Developer',
#   'company': 'Bluestone PIM',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12075', 'high': '17325', 'currency': 'PLN'},
#   'name': 'Remote Mid Java Developer',
#   'company': 'SoftareMill',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18375', 'high': '26775', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'SoftareMill',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Łódź', 'country': 'POL'},
#   'salary': {'low': '12000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Pixel Technology Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18700', 'high': '27400', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Montrose Softare',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Poznań', 'country': 'POL\n + 2'},
#   'salary': {'low': '10000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Backend Java Developer',
#   'company': 'Santander Bank Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'JAVA Developer (Mid/Senior)',
#   'company': 'Stepise',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '19000', 'currency': 'PLN'},
#   'name': 'Java Full-Stack Developer (100% remote)',
#   'company': 'PGS Softare S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '4200', 'high': '6000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'Altkom Softare & Consulting',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '6720', 'high': '11760', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Unity Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '5000', 'high': '8500', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'BlueSoft Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15200', 'high': '21200', 'currency': 'PLN'},
#   'name': 'Java Cloud Developer',
#   'company': 'Grape Up',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '36624', 'high': '51240', 'currency': 'PLN'},
#   'name': 'Tech Lead Java Developer (Remote)',
#   'company': 'ClearScale',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '27100', 'currency': 'PLN'},
#   'name': 'Senior Java Cloud Developer',
#   'company': 'Grape Up',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Łódź', 'country': 'POL'},
#   'salary': {'low': '13300', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Senior Java SE Developer for Automotive',
#   'company': 'HARMAN Connected Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Trójmiasto', 'country': 'POL\n + 2'},
#   'salary': {'low': '14000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Senior IT Developer - Java Backend',
#   'company': 'Nordea Bank ABP',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '17000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'People Trust Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Scala / Java Developer',
#   'company': 'NetorkedAssets',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Java/Kotlin Developer',
#   'company': 'NetorkedAssets Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Poznań Supercomputing and Netorking Center',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Backend Java Developer',
#   'company': 'Margo',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'Stretto',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Białystok', 'country': 'POL\n + 2'},
#   'salary': {'low': '16800', 'high': '26880', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Dynamic Solutions',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Białystok', 'country': 'POL\n + 2'},
#   'salary': {'low': '16800', 'high': '26880', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'Dynamic Solutions',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '22680', 'high': '26880', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Avenga',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Łódź', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Junior/Regular Java Developer',
#   'company': 'HARMAN Connected Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9500', 'high': '19000', 'currency': 'PLN'},
#   'name': 'Remote Java (Hybris) Developer',
#   'company': 'Si e-commerce',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Katowice', 'country': 'POL'},
#   'salary': {'low': '9000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Shiji Poland',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Gdańsk', 'country': 'POL'},
#   'salary': {'low': '3000', 'high': '6000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Marotino',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18900', 'high': '23100', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'ASTEK Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '21840', 'high': '31920', 'currency': 'PLN'},
#   'name': 'The best Java Developer- 100% remote',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '19320', 'high': '26040', 'currency': 'PLN'},
#   'name': 'Java Developer - Remote',
#   'company': 'Tryg Forsikring',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10080', 'high': '16800', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'DevOpsi',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14280', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Scala (Java) Developer',
#   'company': 'Lingaro',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Backend Developer',
#   'company': 'Reality Games',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15750', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer - branża bankowa',
#   'company': 'Sii Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Remote Back-end Java Developer',
#   'company': 'BNY Mellon',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Remote Fullstack Developer Java, Angular',
#   'company': 'BNY Mellon',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java/HTML Developer - Białystok',
#   'company': 'Exorigo-Upos',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'eejscioki.pl',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Gdańsk', 'country': 'POL'},
#   'salary': {'low': '4000', 'high': '5500', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Uniersytet Gdański',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Oferteo',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16300', 'high': '20160', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'ALTEN Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Interactive Workspace',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '23962', 'high': '28754', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Hypatos GmbH',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '17000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Mid/Senior Backend Java Developer Remote',
#   'company': 'Kuehne + Nagel Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Codest Ltd.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Łódź', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '13000', 'currency': 'PLN'},
#   'name': 'Java SE Developer for Automotive',
#   'company': 'HARMAN Connected Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20160', 'high': '23520', 'currency': 'PLN'},
#   'name': 'Middle Java Developer',
#   'company': 'Infopulse',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '6554', 'high': '13108', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Remedy',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'EPAM',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14000', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Lead Java Developer',
#   'company': 'EPAM',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '15120', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Decerto Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16666', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Senior Java Developer - Remote / Hybrid',
#   'company': 'HERE Technologies',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'ING BANK ŚLĄSKI SPÓŁKA AKCYJNA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '23100', 'currency': 'PLN'},
#   'name': 'Regular Java Developer',
#   'company': 'Sii Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Coinfirm',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12600', 'high': '23100', 'currency': 'PLN'},
#   'name': 'Java Test Developer',
#   'company': 'Sii Polska',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '4000', 'high': '7000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Gyfted',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20000', 'high': '35000', 'currency': 'PLN'},
#   'name': 'Remote Java Cloud Developer',
#   'company': 'DahliaMatic Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Appliscale',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '30000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'Nickel Digital Asset Management',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13500', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Backend Developer',
#   'company': 'Kitopi',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '31920', 'high': '38640', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '21840', 'high': '28560', 'currency': 'PLN'},
#   'name': 'Java Developer (Regular/Senior)',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Fulstack Java Developer',
#   'company': 'Metrosoft',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Citi Service Center',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '14300', 'high': '28600', 'currency': 'PLN'},
#   'name': 'Senior Java Developer – Innovation Team',
#   'company': 'Citi Service Center',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL\n + 4'},
#   'salary': {'low': '16000', 'high': '32000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Poer Media',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '32000', 'high': '38000', 'currency': 'PLN'},
#   'name': 'Remote Expert Java Developer',
#   'company': 'BigPicture',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '21847', 'high': '30585', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'MUGCO, LLC.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12600', 'high': '18900', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Onelo S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '19320', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Senior Java Developer with German',
#   'company': 'VM.PL Softare House',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Senior Java Backend Developer',
#   'company': 'VM.PL Softare House',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '13000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'ERGO Technology & Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '21565', 'high': '28754', 'currency': 'PLN'},
#   'name': 'Senior Java Developer R&D',
#   'company': 'Vaadin',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Łódź', 'country': 'POL\n + 1'},
#   'salary': {'low': '14280', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Hays Poland',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '23520', 'high': '28560', 'currency': 'PLN'},
#   'name': 'Java Backend Developer',
#   'company': 'Green Minds Sp.z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16000', 'high': '28000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Knode',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '13000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'SafeKiddo sp. z o.o. sp. k.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Junior Integration Developer (Java)',
#   'company': 'Qurate Retail Group Global Business Services sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Cisco',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Java developer',
#   'company': 'Chargify',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'Deskset Softare Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '29400', 'currency': 'PLN'},
#   'name': 'Senior/Tech Lead Java Developer',
#   'company': 'Spyrosoft',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '6000', 'high': '11000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Nekken',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10080', 'high': '16800', 'currency': 'PLN'},
#   'name': 'Java Developer (Microservices)',
#   'company': 'ConSol Austria Softare GmbH',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '9000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Poznań Supercomputing and Netorking Center',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '19500', 'high': '25760', 'currency': 'PLN'},
#   'name': 'Java Game Developer',
#   'company': 'Evolution',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer (Service mesh)',
#   'company': 'ING BANK ŚLĄSKI SPÓŁKA AKCYJNA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13440', 'high': '21840', 'currency': 'PLN'},
#   'name': 'Java Developer | FinTech',
#   'company': 'JCommerce Sp z o o',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8786', 'high': '9984', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Anya Consultancy Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Citi Service Center',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '14300', 'high': '28600', 'currency': 'PLN'},
#   'name': 'Lead Java Developer',
#   'company': 'Citi Service Center',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '17500', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Positive Geeks Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '15000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'AMSORT Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'Solit SA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '11000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Przedsiębiorsto Państoe „Porty Lotnicze”',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '21840', 'high': '23520', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'JCommerce Sp z o o',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '17640', 'high': '21840', 'currency': 'PLN'},
#   'name': 'ANDROID DEVELOPER | JAVA, KOTLIN',
#   'company': 'JCommerce Sp z o o',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '22000', 'high': '30000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'SquareOne',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '18480', 'high': '21840', 'currency': 'PLN'},
#   'name': 'Fullstack Developer (Java + Angular)',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '20160', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'People Trust Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20000', 'high': '26000', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Backend Developer',
#   'company': 'Kontomatik Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16000', 'high': '32000', 'currency': 'PLN'},
#   'name': 'Java Developer - 100%  remote',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Bravura Solutions Polska Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11880', 'high': '23760', 'currency': 'PLN'},
#   'name': 'Remote Mid/Senior Java Developer',
#   'company': 'Espeo Softare',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Java/Kotlin Developer',
#   'company': 'Kinguin Poland Sp. z o. o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '26880', 'currency': 'PLN'},
#   'name': 'Java Software Developer',
#   'company': 'IN Team',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12500', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'CrustLab',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wroclaw', 'country': 'POL'},
#   'salary': {'low': '16000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'FIS Techlology Services (Poland) Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20973', 'high': '27527', 'currency': 'PLN'},
#   'name': 'Remote Lead Backend Java Developer',
#   'company': 'Softengi',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'Clurgo Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '24360', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '30240', 'high': '36960', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '15000', 'high': '20500', 'currency': 'PLN'},
#   'name': 'Senior Java Software Developer',
#   'company': 'Volvo Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13300', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Java Fullstack Developer',
#   'company': 'Syncron Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Inteca',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Fullstack Java Developer',
#   'company': 'InfiniteProgress',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Exorigo-Upos',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': None,
#   'name': 'Remote Senior Java Developer',
#   'company': 'gravit.dev',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': None,
#   'name': 'Remote Mid Java Developer',
#   'company': 'gravit.dev',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer (mid/senior)',
#   'company': 'Amusys Production Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Developer (mid/senior)',
#   'company': 'Amusys Production Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'FullStack Developer (Java/React)',
#   'company': 'A4BEE Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Onelo S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '14000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Fullstack Java Mobile Developer',
#   'company': 'Eternis Sp. z o.o. Sp. k.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18816', 'high': '26880', 'currency': 'PLN'},
#   'name': 'Senior Java Developer',
#   'company': 'Codibly',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'DXC Technology',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18480', 'high': '26040', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Mid Java Developer',
#   'company': 'Acaisoft Poland Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '20000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Itransition',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Java Developer (remote)',
#   'company': 'IN Team',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '13000', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Fullstack Developer (Java, React)',
#   'company': 'Link Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Kraków', 'country': 'POL'},
#   'salary': {'low': '6888', 'high': '11760', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Codibly',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Full Stack Java Developer',
#   'company': 'OakFusion',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '17000', 'currency': 'PLN'},
#   'name': 'Remote Java Developer',
#   'company': 'EXATEL S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '20160', 'currency': 'PLN'},
#   'name': 'Java Developer (Mid/Senior)',
#   'company': 'BCF Softare Sp. z o. o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12600', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Clurgo Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '14280', 'high': '19320', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Clurgo Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '6000', 'high': '8000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'KRUK S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Bydgoszcz', 'country': 'POL'},
#   'salary': {'low': '3000', 'high': '6000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'PRIMIGENIUS',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '8000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Junior Java/HTML Developer (Remote)',
#   'company': 'Exorigo-Upos',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '7000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'Viercode',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '25200', 'high': '31920', 'currency': 'PLN'},
#   'name': 'Remote Senior Java Developer',
#   'company': 'Link Group',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '19000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devire Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 3'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'BMS',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '30240', 'high': '35280', 'currency': 'PLN'},
#   'name': 'Fullstack Java Developer',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Java Developer (Junior - Mid -Senior)',
#   'company': 'PayU',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '30240', 'currency': 'PLN'},
#   'name': 'JAVA SOFTWARE DEVELOPER',
#   'company': 'RMEDISON SP Z O.O.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '15000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Mid/Senior Java Developer',
#   'company': 'ERGO Technology & Services',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20160', 'high': '25200', 'currency': 'PLN'},
#   'name': 'Java Developer',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '5500', 'high': '8400', 'currency': 'PLN'},
#   'name': 'Junior Java Developer',
#   'company': 'TouK',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11000', 'high': '19000', 'currency': 'PLN'},
#   'name': 'Java Developer (100% remote)',
#   'company': 'PGS Softare S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '25000', 'currency': 'PLN'},
#   'name': 'Senior/Principal Java Developer',
#   'company': 'PGS Softare S.A.',
#   'technology': 'N/A',
#   'job': 'java developer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Full Stack Senior Java Developer',
#   'company': 'Sky and Space Co',
#   'technology': 'N/A',
#   'job': 'java developer'}]
