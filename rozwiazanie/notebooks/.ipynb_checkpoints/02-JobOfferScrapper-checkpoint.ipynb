# %%
import pandas as pd
import re
import os

from bs4 import BeautifulSoup

# %%
def is_page_empty(bs) -> bool:
    empty_condition = bs.find('h2', class_='text-white font-weight-bold')

    if empty_condition is None:
        return False
    else:
        return True

# %%
def parse_salary(salary) -> dict:
    bounds = re.findall('[0-9]+', salary.replace(' ', ''))
    low_bound = bounds[0]
    high_bound = bounds[1] if len(bounds) > 1 else bounds[0]
    currency = salary.split()[-1]

    return {'low': low_bound,
            'high': high_bound,
            'currency': currency}

# %%
def parse_city(city) -> dict:
    if re.search('(Zdalna)', city):
         _city = "Zdalna"
         country = 'N/A'
    else:       
        (_city, country) = city.split(',')
        country = country.strip()

    return {'city': _city, 'country': country}

# %%
def parse_jobs(jobs) -> list:
    results = []
    
    for job in jobs:
        results.append(parse_job(job))

    return results

# %%
def parse_job(job) -> dict:
    job_info = job.find('div', class_='posting-info position-relative d-none d-lg-flex flex-grow-1').find_all('span')
    
    salary = job_info[0].text.strip()
    salary_data = parse_salary(salary)
    
    location = job.find('nfj-posting-item-city')
    if location is None:
        location = job_info[1]

    location = location.text.strip()
    location = parse_city(location)

    name = job.find('h2', class_='posting-title__position').text.strip()
    
    company = job.find('span', class_='posting-title__company').text.replace('w', '').strip()

    technology = job.find('a', class_='btn btn-outline-secondary btn-sm text-truncate')
    if technology:
        technology = technology.text.strip()
    else:
        technology = 'N/A'

    return {
        'location': location,
        'salary': salary_data,
        'name': name,
        'company': company,
        'technology': technology
    }

# %%
def get_data(page) -> list:
    results = []

    jobs = [x.parent for x in page.find_all('div', class_='posting-image')]
    page_data = parse_jobs(jobs)
    results += page_data

    return results

# %%
data_dir = '../data/raw'
results = []

for entry in os.scandir(data_dir):
    with open(
        os.path.join(data_dir, entry.name),
        encoding='UTF-8') as f:
            html = f.read()

    job = entry.name.split('_')[0]
    bs = BeautifulSoup(html)
    
    offers = get_data(bs)
    for offer in offers:
        offer['job'] = job
    results += offers

# %%
offers
# Out:
# [{'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '13000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'NatWest Group',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '9000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Time S.A.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '19320', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': '7N Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Ceneo.pl',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Talent Place',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '16000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Senior Data Scientist',
#   'company': 'Sages',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Nevomo IOT sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'relayr sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9567', 'high': '12757', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'IDBC Creative Solutions Kft.',
#   'technology': 'N/A',
#   'job': 'data scientist'}]

# %%
df = pd.json_normalize(results, sep='_')
df.head()
# Out:
#                       name                 company technology           job  \
# 0             Data Analyst                  AVENGA        N/A  data analyst
# 1          Python Engineer            ASTEK Polska        N/A  data analyst
# 2  Data Scientist (senior)  PRUFTECHNIK Technology        N/A  data analyst
# 3             Data Analyst            Siepomaga.pl        N/A  data analyst
# 4            Data Engineer                 Brytlyt        N/A  data analyst
#
#   location_city location_country salary_low salary_high salary_currency
# 0        Zdalna              N/A      15120       18480             PLN
# 1        Zdalna              N/A      17430       20160             PLN
# 2       Wrocław              POL      15540       21460             PLN
# 3        Poznań              POL       7000       14000             PLN
# 4        Zdalna              N/A      10000       18000             PLN

# %%
df.to_csv('../data/interim/job_offers.csv', sep=';', encoding='UTF', index=False)

# %%
results
# Out:
# [{'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15120', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '17430', 'high': '20160', 'currency': 'PLN'},
#   'name': 'Python Engineer',
#   'company': 'ASTEK Polska',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '15540', 'high': '21460', 'currency': 'PLN'},
#   'name': 'Data Scientist (senior)',
#   'company': 'PRUFTECHNIK Technology',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'Siepomaga.pl',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Brytlyt',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Kraków', 'country': 'POL'},
#   'salary': {'low': '4000', 'high': '7000', 'currency': 'PLN'},
#   'name': 'PM / PM Office',
#   'company': 'Opsenio',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16000', 'high': '22000', 'currency': 'PLN'},
#   'name': 'Senior UX Researcher / Designer',
#   'company': 'VirtusLab',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '8000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'RTB House',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '19950', 'high': '27300', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '12000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'QA/Test Analyst',
#   'company': 'Link Group Sp. z o. o.',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 2'},
#   'salary': {'low': '8000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'Ringier Axel Springer Tech',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '8000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'GfK Polonia sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '8000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'IIIT',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'Aesculap Chifa Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '4500', 'high': '9000', 'currency': 'PLN'},
#   'name': 'Data Analyst (Python + PostgreSQL)',
#   'company': 'Sunscrapers Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '13000', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '15000', 'currency': 'PLN'},
#   'name': 'Senior Product Data Analyst',
#   'company': 'Grupa OLX',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Gdańsk', 'country': 'POL\n + 1'},
#   'salary': {'low': '16800', 'high': '18480', 'currency': 'PLN'},
#   'name': 'IT Analyst',
#   'company': 'ProData Consult',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10205', 'high': '19135', 'currency': 'PLN'},
#   'name': 'Data Analyst',
#   'company': 'Antavo Informatikai Kft.',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Kiev', 'country': 'UKR'},
#   'salary': {'low': '7645', 'high': '12232', 'currency': 'PLN'},
#   'name': 'Project Manager',
#   'company': 'Conversion Rate Store',
#   'technology': 'N/A',
#   'job': 'data analyst'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '14000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'GOG',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '10000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Brytlyt',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 2'},
#   'salary': {'low': '15120', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Link Group',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '18900', 'high': '31500', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Mindbox',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'McKinsey & Company',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '23520', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'STX Next',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Gdańsk', 'country': 'POL'},
#   'salary': {'low': '14000', 'high': '23000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Dynatrace Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '20160', 'high': '21840', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'ProData Consult',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Poznań', 'country': 'POL'},
#   'salary': {'low': '7000', 'high': '12000', 'currency': 'PLN'},
#   'name': 'DATA ENGINEER',
#   'company': 'TIDK Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '23000', 'high': '27000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'DevsData LLC',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '8300', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Packhelp',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Nevomo IOT sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Warszawa', 'country': 'POL\n + 2'},
#   'salary': {'low': '15000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Payability',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Kiev', 'country': 'UKR'},
#   'salary': {'low': '11467', 'high': '19112', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Daxx',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '10205', 'high': '15308', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'MP Solutions Kft.',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Budapest', 'country': 'HUN'},
#   'salary': {'low': '20391', 'high': '29883', 'currency': 'PLN'},
#   'name': 'Data engineer',
#   'company': 'IDBC Creative Solutions Kft.',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Budaörs', 'country': 'HUN'},
#   'salary': {'low': '14032', 'high': '17859', 'currency': 'PLN'},
#   'name': 'Data Engineer',
#   'company': 'Collective Consulting Kft.',
#   'technology': 'N/A',
#   'job': 'data engineer'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '5000', 'high': '10000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Devire',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warsaw', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '13000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'NatWest Group',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '9000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Time S.A.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '11760', 'high': '19320', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': '7N Sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Wrocław', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '14000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Ceneo.pl',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '16800', 'high': '18480', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Talent Place',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '18000', 'high': '21000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'AVENGA',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '16000', 'high': '18000', 'currency': 'PLN'},
#   'name': 'Senior Data Scientist',
#   'company': 'Sages',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Warszawa', 'country': 'POL'},
#   'salary': {'low': '10000', 'high': '16000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'Nevomo IOT sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '15000', 'high': '24000', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'relayr sp. z o.o.',
#   'technology': 'N/A',
#   'job': 'data scientist'},
#  {'location': {'city': 'Zdalna', 'country': 'N/A'},
#   'salary': {'low': '9567', 'high': '12757', 'currency': 'PLN'},
#   'name': 'Data Scientist',
#   'company': 'IDBC Creative Solutions Kft.',
#   'technology': 'N/A',
#   'job': 'data scientist'}]
